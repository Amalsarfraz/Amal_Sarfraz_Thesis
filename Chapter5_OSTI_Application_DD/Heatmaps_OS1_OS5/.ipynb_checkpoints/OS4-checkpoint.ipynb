# %%
import pandas as pd
df = pd.read_pickle('df_OS4.pkl')
df
# Out:
#                                        scenario  gw  res  esm  tax  ssp  ag  \
# 0        ssp_ag4_soc5_gwhi_exp_ipsl_NDC_Tax_uct   3    2    3    2    2   4
# 1      ssp_ag4_soc5_gwhi_exp_noresm_NDC_Tax_uct   3    2    5    2    2   4
# 2         ssp_ag4_soc5_gwhi_rs_ipsl_NDC_Tax_uct   3    1    3    2    2   4
# 3       ssp_ag4_soc5_gwhi_rs_noresm_NDC_Tax_uct   3    1    5    2    2   4
# 4      ssp_ag4_soc5_gwlo_exp_gfdl_NDC_Tax_ffict   1    2    1    1    2   4
# 5        ssp_ag4_soc5_gwlo_exp_gfdl_NDC_Tax_uct   1    2    1    2    2   4
# 6    ssp_ag4_soc5_gwlo_exp_hadgem_NDC_Tax_ffict   1    2    2    1    2   4
# 7      ssp_ag4_soc5_gwlo_exp_hadgem_NDC_Tax_uct   1    2    2    2    2   4
# 8      ssp_ag4_soc5_gwlo_exp_ipsl_NDC_Tax_ffict   1    2    3    1    2   4
# 9        ssp_ag4_soc5_gwlo_exp_ipsl_NDC_Tax_uct   1    2    3    2    2   4
# 10    ssp_ag4_soc5_gwlo_exp_miroc_NDC_Tax_ffict   1    2    4    1    2   4
# 11      ssp_ag4_soc5_gwlo_exp_miroc_NDC_Tax_uct   1    2    4    2    2   4
# 12   ssp_ag4_soc5_gwlo_exp_noresm_NDC_Tax_ffict   1    2    5    1    2   4
# 13     ssp_ag4_soc5_gwlo_exp_noresm_NDC_Tax_uct   1    2    5    2    2   4
# 14      ssp_ag4_soc5_gwlo_rs_gfdl_NDC_Tax_ffict   1    1    1    1    2   4
# 15        ssp_ag4_soc5_gwlo_rs_gfdl_NDC_Tax_uct   1    1    1    2    2   4
# 16    ssp_ag4_soc5_gwlo_rs_hadgem_NDC_Tax_ffict   1    1    2    1    2   4
# 17      ssp_ag4_soc5_gwlo_rs_hadgem_NDC_Tax_uct   1    1    2    2    2   4
# 18      ssp_ag4_soc5_gwlo_rs_ipsl_NDC_Tax_ffict   1    1    3    1    2   4
# 19        ssp_ag4_soc5_gwlo_rs_ipsl_NDC_Tax_uct   1    1    3    2    2   4
# 20     ssp_ag4_soc5_gwlo_rs_miroc_NDC_Tax_ffict   1    1    4    1    2   4
# 21       ssp_ag4_soc5_gwlo_rs_miroc_NDC_Tax_uct   1    1    4    2    2   4
# 22    ssp_ag4_soc5_gwlo_rs_noresm_NDC_Tax_ffict   1    1    5    1    2   4
# 23      ssp_ag4_soc5_gwlo_rs_noresm_NDC_Tax_uct   1    1    5    2    2   4
# 24      ssp_ag4_soc5_gwmed_exp_gfdl_NDC_Tax_uct   2    2    1    2    2   4
# 25    ssp_ag4_soc5_gwmed_exp_ipsl_NDC_Tax_ffict   2    2    3    1    2   4
# 26      ssp_ag4_soc5_gwmed_exp_ipsl_NDC_Tax_uct   2    2    3    2    2   4
# 27     ssp_ag4_soc5_gwmed_exp_miroc_NDC_Tax_uct   2    2    4    2    2   4
# 28  ssp_ag4_soc5_gwmed_exp_noresm_NDC_Tax_ffict   2    2    5    1    2   4
# 29    ssp_ag4_soc5_gwmed_exp_noresm_NDC_Tax_uct   2    2    5    2    2   4
# 30       ssp_ag4_soc5_gwmed_rs_gfdl_NDC_Tax_uct   2    1    1    2    2   4
# 31     ssp_ag4_soc5_gwmed_rs_ipsl_NDC_Tax_ffict   2    1    3    1    2   4
# 32       ssp_ag4_soc5_gwmed_rs_ipsl_NDC_Tax_uct   2    1    3    2    2   4
# 33    ssp_ag4_soc5_gwmed_rs_miroc_NDC_Tax_ffict   2    1    4    1    2   4
# 34      ssp_ag4_soc5_gwmed_rs_miroc_NDC_Tax_uct   2    1    4    2    2   4
# 35   ssp_ag4_soc5_gwmed_rs_noresm_NDC_Tax_ffict   2    1    5    1    2   4
# 36     ssp_ag4_soc5_gwmed_rs_noresm_NDC_Tax_uct   2    1    5    2    2   4
# 37     ssp_ag4_soc5_gwhi_exp_gfdl_NDC_Tax_ffict   3    2    1    1    2   4
# 38       ssp_ag4_soc5_gwhi_exp_gfdl_NDC_Tax_uct   3    2    1    2    2   4
# 39   ssp_ag4_soc5_gwhi_exp_hadgem_NDC_Tax_ffict   3    2    2    1    2   4
# 40     ssp_ag4_soc5_gwhi_exp_hadgem_NDC_Tax_uct   3    2    2    2    2   4
# 41     ssp_ag4_soc5_gwhi_exp_ipsl_NDC_Tax_ffict   3    2    3    1    2   4
# 43    ssp_ag4_soc5_gwhi_exp_miroc_NDC_Tax_ffict   3    2    4    1    2   4
# 44      ssp_ag4_soc5_gwhi_exp_miroc_NDC_Tax_uct   3    2    4    2    2   4
# 45   ssp_ag4_soc5_gwhi_exp_noresm_NDC_Tax_ffict   3    2    5    1    2   4
# 47      ssp_ag4_soc5_gwhi_rs_gfdl_NDC_Tax_ffict   3    1    1    1    2   4
# 48        ssp_ag4_soc5_gwhi_rs_gfdl_NDC_Tax_uct   3    1    1    2    2   4
# 49    ssp_ag4_soc5_gwhi_rs_hadgem_NDC_Tax_ffict   3    1    2    1    2   4
# 50      ssp_ag4_soc5_gwhi_rs_hadgem_NDC_Tax_uct   3    1    2    2    2   4
# 51      ssp_ag4_soc5_gwhi_rs_ipsl_NDC_Tax_ffict   3    1    3    1    2   4
# 53     ssp_ag4_soc5_gwhi_rs_miroc_NDC_Tax_ffict   3    1    4    1    2   4
# 54       ssp_ag4_soc5_gwhi_rs_miroc_NDC_Tax_uct   3    1    4    2    2   4
# 55    ssp_ag4_soc5_gwhi_rs_noresm_NDC_Tax_ffict   3    1    5    1    2   4
# 77    ssp_ag4_soc5_gwmed_exp_gfdl_NDC_Tax_ffict   2    2    1    1    2   4
# 79  ssp_ag4_soc5_gwmed_exp_hadgem_NDC_Tax_ffict   2    2    2    1    2   4
# 80    ssp_ag4_soc5_gwmed_exp_hadgem_NDC_Tax_uct   2    2    2    2    2   4
# 83   ssp_ag4_soc5_gwmed_exp_miroc_NDC_Tax_ffict   2    2    4    1    2   4
# 87     ssp_ag4_soc5_gwmed_rs_gfdl_NDC_Tax_ffict   2    1    1    1    2   4
# 89   ssp_ag4_soc5_gwmed_rs_hadgem_NDC_Tax_ffict   2    1    2    1    2   4
# 90     ssp_ag4_soc5_gwmed_rs_hadgem_NDC_Tax_uct   2    1    2    2    2   4
#
#     soc
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5
# 5     5
# 6     5
# 7     5
# 8     5
# 9     5
# 10    5
# 11    5
# 12    5
# 13    5
# 14    5
# 15    5
# 16    5
# 17    5
# 18    5
# 19    5
# 20    5
# 21    5
# 22    5
# 23    5
# 24    5
# 25    5
# 26    5
# 27    5
# 28    5
# 29    5
# 30    5
# 31    5
# 32    5
# 33    5
# 34    5
# 35    5
# 36    5
# 37    5
# 38    5
# 39    5
# 40    5
# 41    5
# 43    5
# 44    5
# 45    5
# 47    5
# 48    5
# 49    5
# 50    5
# 51    5
# 53    5
# 54    5
# 55    5
# 77    5
# 79    5
# 80    5
# 83    5
# 87    5
# 89    5
# 90    5

# %%
columns = ['gw', 'res', 'esm', 'tax', 'ssp', 'ag', 'soc']

# Print unique values for each specified column
for column in columns:
    unique_values = df[column].unique()
    print(f"Unique values in '{column}': {unique_values}")
# Out:
# Unique values in 'gw': [3 1 2]
# Unique values in 'res': [2 1]
# Unique values in 'esm': [3 5 1 2 4]
# Unique values in 'tax': [2 1]
# Unique values in 'ssp': [2]
# Unique values in 'ag': [4]
# Unique values in 'soc': [5]

# %%
columns = ['gw', 'res', 'esm', 'tax', 'ssp', 'ag', 'soc']

# Print unique values and their counts for each specified column
for column in columns:
    unique_values = df[column].unique()
    count = len(unique_values)
    print(f"Unique values in '{column}': {unique_values}")


# Print frequency of each unique value for each specified column
for column in columns:
    value_counts = df[column].value_counts()
    print(f"Frequencies in '{column}':\n{value_counts}\n")
# Out:
# Unique values in 'gw': [3 1 2]
# Unique values in 'res': [2 1]
# Unique values in 'esm': [3 5 1 2 4]
# Unique values in 'tax': [2 1]
# Unique values in 'ssp': [2]
# Unique values in 'ag': [4]
# Unique values in 'soc': [5]
# Frequencies in 'gw':
# gw
# 3    20
# 1    20
# 2    20
# Name: count, dtype: int64
#
# Frequencies in 'res':
# res
# 2    30
# 1    30
# Name: count, dtype: int64
#
# Frequencies in 'esm':
# esm
# 3    12
# 5    12
# 1    12
# 2    12
# 4    12
# Name: count, dtype: int64
#
# Frequencies in 'tax':
# tax
# 2    30
# 1    30
# Name: count, dtype: int64
#
# Frequencies in 'ssp':
# ssp
# 2    60
# Name: count, dtype: int64
#
# Frequencies in 'ag':
# ag
# 4    60
# Name: count, dtype: int64
#
# Frequencies in 'soc':
# soc
# 5    60
# Name: count, dtype: int64

# %%
import os 
import pandas as pd


df=pd.read_csv('OS_4_BOI_scenarios/OS4_count_sum/consolidated_scenarios_OS4.csv')
# Ensure 'Count' is numeric
df['Count'] = pd.to_numeric(df['Count'])
df=df.dropna()
df

df['Input'] = df['Input'].str.replace('water_td_irr_', '')
df['Input'] = df['Input'].str.replace('_W', '')

df['Input'].unique()

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


plt.rcParams.update({
    'axes.titlesize': 16,     # Title font size
    'axes.labelsize': 14,     # Axis label font size
    'xtick.labelsize': 14,    # X-axis tick label font size
    'ytick.labelsize': 14,    # Y-axis tick label font size
    'legend.fontsize': 14,    # Legend font size
    'figure.titlesize': 18    # Figure title font size
})

df['Combination'] = df['Combination'].replace({'FiberCrop': 'Cotton', 'SugarCrop': 'Sugarcane', 'MiscAll': 'Miscellaneous'}, regex=True)

# Extract crop names from combinations
df['Crop1'] = df['Combination'].apply(lambda x: x.split(' vs ')[0].split('_')[0])
df['Crop2'] = df['Combination'].apply(lambda x: x.split(' vs ')[1].split('_')[0])

# Create a new column with sorted crop pairs
df['CropPair'] = df.apply(lambda row: '_'.join(sorted([row['Crop1'], row['Crop2']])), axis=1)

# Create a pivot table with the new CropPair column
pivot_data_crops = df.pivot_table(values='Count', index='Input', columns='CropPair', aggfunc='sum', fill_value=0)

# Find the highest count and how many times it appears
highest_count = pivot_data_crops.max().max()
highest_count_appearances = (pivot_data_crops == highest_count).sum().sum()

# Sum the total counts of each cell
total_counts = pivot_data_crops.values.sum()

# Create the heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(pivot_data_crops, annot=True, fmt='d', cmap='YlOrRd')
plt.title('OS 4 Heatmap of Crop Pairs Across Regions')
plt.xlabel('Crop Pair')
plt.ylabel('Region')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('OS4_60_scenarios_heatmap_croppairs_regions.png', dpi=600, bbox_inches='tight')
plt.show()

# Display the highest count and total counts
print(f"The highest count is {highest_count} and it appears {highest_count_appearances} times.")
print(f"The total sum of counts across all cells is {total_counts}.")
# Out:
# The highest count is 60 and it appears 16 times.
# The total sum of counts across all cells is 1428.
